# %%
# Create a new set of 2,000 random latitudes and Longitudes
#Get the neaest city using citipy
#Perform and API call with OpenWeatherMap
#Retreive the following information from the API Call: 
#Latitude and Longitude,Maximum Temperature, Percent Humidity, Percent Cloudiness, Wind Speed,Weaterh Description.  
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-60.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-125.000, high=190.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 911

# %%
# Import the requests library.
import requests

# Import the time library.
import time

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "b4b432a06406fcca5949d2e4ee7a565f"

# %%
#Retreive the following information from the API call.
#latitude and longitude, max temp, % humidity, %cloudiness, wind speed, weather description

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Print the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("Data Retrieval Complete")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atikokan
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | souillac
# Processing Record 4 of Set 1 | ancud
# Processing Record 5 of Set 1 | salalah
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | codrington
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | kovur
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | saskylakh
# Processing Record 14 of Set 1 | hillsborough
# Processing Record 15 of Set 1 | fraserburgh
# Processing Record 16 of Set 1 | wajima
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | nikolskoye
# Processing Record 19 of Set 1 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 1 | pringsewu
# Processing Record 21 of Set 1 | asau
# Processing Record 22 of Set 1 | cordoba
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | nanortalik
# Processing Record 26 of Set 1 | machaneng
# Processing Record 27 of Set 1 | kisangani
# Processing Record 28 of Set 1 | mareeba
# Processing Record 29 of Set 1 | mogadishu
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | bambous virieux
# Processing Record 32 of Set 1 | te anau
# Processing Record 33 of Set 1 | clyde river
# Processing Record 34 of Set 1 | myaundzha
# Processing Record 35 of Set 1 | vardo
# Processing Record 36 of Set 1 | chimore
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | san vicente
# Processing Record 39 of Set 1 | northam
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | necochea
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | severo-kurilsk
# Processing Record 44 of Set 1 | mount gambier
# Processing Record 45 of Set 1 | norman wells
# Processing Record 46 of Set 1 | doha
# Processing Record 47 of Set 1 | conceicao do araguaia
# Processing Record 48 of Set 1 | ponta do sol
# Processing Record 49 of Set 1 | havoysund
# Processing Record 50 of Set 1 | dingle
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | coihueco
# Processing Record 4 of Set 2 | daru
# Processing Record 5 of Set 2 | black river
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | nantucket
# Processing Record 8 of Set 2 | thunder bay
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | khipro
# Processing Record 11 of Set 2 | upernavik
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | auki
# Processing Record 14 of Set 2 | uaua
# Processing Record 15 of Set 2 | katsuura
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | wagar
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | carmelo
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | lasa
# Processing Record 22 of Set 2 | vila velha
# Processing Record 23 of Set 2 | sibolga
# Processing Record 24 of Set 2 | dunedin
# Processing Record 25 of Set 2 | tromso
# Processing Record 26 of Set 2 | les cayes
# Processing Record 27 of Set 2 | san cristobal
# Processing Record 28 of Set 2 | baracoa
# Processing Record 29 of Set 2 | gobabis
# Processing Record 30 of Set 2 | san patricio
# Processing Record 31 of Set 2 | tuatapere
# Processing Record 32 of Set 2 | pavino
# Processing Record 33 of Set 2 | kavaratti
# Processing Record 34 of Set 2 | atasu
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | visby
# Processing Record 37 of Set 2 | burnie
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | acapulco
# Processing Record 40 of Set 2 | ust-kuyga
# Processing Record 41 of Set 2 | viru
# Processing Record 42 of Set 2 | erenhot
# Processing Record 43 of Set 2 | axixa do tocantins
# City not found. Skipping...
# Processing Record 44 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | barmer
# Processing Record 47 of Set 2 | ahmadpur sial
# Processing Record 48 of Set 2 | mahibadhoo
# Processing Record 49 of Set 2 | beringovskiy
# Processing Record 50 of Set 2 | cockburn town
# Processing Record 1 of Set 3 | bengkulu
# Processing Record 2 of Set 3 | rio grande
# Processing Record 3 of Set 3 | san quintin
# Processing Record 4 of Set 3 | tura
# Processing Record 5 of Set 3 | sao miguel do araguaia
# Processing Record 6 of Set 3 | terenos
# Processing Record 7 of Set 3 | aleksandrov gay
# Processing Record 8 of Set 3 | chuy
# Processing Record 9 of Set 3 | fortuna
# Processing Record 10 of Set 3 | itainopolis
# Processing Record 11 of Set 3 | hamilton
# Processing Record 12 of Set 3 | klaksvik
# Processing Record 13 of Set 3 | meulaboh
# Processing Record 14 of Set 3 | sao joao da barra
# Processing Record 15 of Set 3 | indramayu
# Processing Record 16 of Set 3 | sinnamary
# Processing Record 17 of Set 3 | chalmette
# Processing Record 18 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 19 of Set 3 | arraial do cabo
# Processing Record 20 of Set 3 | hermanus
# Processing Record 21 of Set 3 | mildura
# Processing Record 22 of Set 3 | encheng
# Processing Record 23 of Set 3 | lamballe
# Processing Record 24 of Set 3 | marv dasht
# City not found. Skipping...
# Processing Record 25 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 3 | hofn
# Processing Record 27 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 3 | victoria point
# Processing Record 29 of Set 3 | novaya ladoga
# Processing Record 30 of Set 3 | fort nelson
# Processing Record 31 of Set 3 | la ronge
# Processing Record 32 of Set 3 | westport
# Processing Record 33 of Set 3 | puerto colombia
# Processing Record 34 of Set 3 | pimentel
# Processing Record 35 of Set 3 | wakkanai
# Processing Record 36 of Set 3 | san andres
# Processing Record 37 of Set 3 | copiapo
# Processing Record 38 of Set 3 | puerto ayora
# Processing Record 39 of Set 3 | belaya gora
# Processing Record 40 of Set 3 | durusu
# Processing Record 41 of Set 3 | seddon
# Processing Record 42 of Set 3 | ushuaia
# Processing Record 43 of Set 3 | mananjary
# Processing Record 44 of Set 3 | saint george
# Processing Record 45 of Set 3 | vaike-maarja
# Processing Record 46 of Set 3 | tolaga bay
# Processing Record 47 of Set 3 | georgetown
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | abu jubayhah
# City not found. Skipping...
# Processing Record 50 of Set 3 | nylstroom
# City not found. Skipping...
# Processing Record 1 of Set 4 | cedar city
# Processing Record 2 of Set 4 | dapaong
# Processing Record 3 of Set 4 | coquimbo
# Processing Record 4 of Set 4 | mount darwin
# Processing Record 5 of Set 4 | warrnambool
# Processing Record 6 of Set 4 | shaowu
# Processing Record 7 of Set 4 | ailigandi
# Processing Record 8 of Set 4 | bolshoye murashkino
# Processing Record 9 of Set 4 | airai
# Processing Record 10 of Set 4 | trat
# Processing Record 11 of Set 4 | biltine
# Processing Record 12 of Set 4 | mandalgovi
# Processing Record 13 of Set 4 | chokurdakh
# Processing Record 14 of Set 4 | abaete
# Processing Record 15 of Set 4 | xining
# Processing Record 16 of Set 4 | parrita
# Processing Record 17 of Set 4 | blythe
# Processing Record 18 of Set 4 | namanga
# Processing Record 19 of Set 4 | grindavik
# Processing Record 20 of Set 4 | cilegon
# Processing Record 21 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 4 | tuktoyaktuk
# Processing Record 23 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 4 | chaoyang
# Processing Record 25 of Set 4 | sibu
# Processing Record 26 of Set 4 | longyearbyen
# Processing Record 27 of Set 4 | pisco
# Processing Record 28 of Set 4 | tiksi
# Processing Record 29 of Set 4 | pangnirtung
# Processing Record 30 of Set 4 | kirakira
# Processing Record 31 of Set 4 | mahebourg
# Processing Record 32 of Set 4 | port elizabeth
# Processing Record 33 of Set 4 | koungou
# Processing Record 34 of Set 4 | caravelas
# Processing Record 35 of Set 4 | mehamn
# Processing Record 36 of Set 4 | leningradskiy
# Processing Record 37 of Set 4 | marzuq
# Processing Record 38 of Set 4 | rio pardo
# Processing Record 39 of Set 4 | bure
# Processing Record 40 of Set 4 | vuktyl
# Processing Record 41 of Set 4 | altona
# Processing Record 42 of Set 4 | svetlograd
# Processing Record 43 of Set 4 | qaanaaq
# Processing Record 44 of Set 4 | takoradi
# Processing Record 45 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 4 | narsaq
# Processing Record 47 of Set 4 | pincher creek
# Processing Record 48 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 4 | maceio
# Processing Record 50 of Set 4 | marsaxlokk
# Processing Record 1 of Set 5 | ayr
# Processing Record 2 of Set 5 | jinka
# Processing Record 3 of Set 5 | blagoyevo
# Processing Record 4 of Set 5 | tasiilaq
# Processing Record 5 of Set 5 | pilar
# Processing Record 6 of Set 5 | gumdag
# Processing Record 7 of Set 5 | mount isa
# Processing Record 8 of Set 5 | pevek
# Processing Record 9 of Set 5 | tabou
# Processing Record 10 of Set 5 | saint-joseph
# Processing Record 11 of Set 5 | husavik
# Processing Record 12 of Set 5 | khandyga
# Processing Record 13 of Set 5 | cherskiy
# Processing Record 14 of Set 5 | wanning
# Processing Record 15 of Set 5 | gonaives
# Processing Record 16 of Set 5 | brechin
# Processing Record 17 of Set 5 | kedougou
# Processing Record 18 of Set 5 | jiuquan
# Processing Record 19 of Set 5 | gigmoto
# Processing Record 20 of Set 5 | sao filipe
# Processing Record 21 of Set 5 | san carlos de bariloche
# Processing Record 22 of Set 5 | yazd
# Processing Record 23 of Set 5 | nemuro
# Processing Record 24 of Set 5 | lata
# Processing Record 25 of Set 5 | churachandpur
# Processing Record 26 of Set 5 | margate
# Processing Record 27 of Set 5 | kiama
# Processing Record 28 of Set 5 | mawlaik
# Processing Record 29 of Set 5 | sayyan
# Processing Record 30 of Set 5 | myitkyina
# Processing Record 31 of Set 5 | rebrikha
# Processing Record 32 of Set 5 | talnakh
# Processing Record 33 of Set 5 | grand gaube
# Processing Record 34 of Set 5 | vostok
# Processing Record 35 of Set 5 | trairi
# Processing Record 36 of Set 5 | per
# Processing Record 37 of Set 5 | yulara
# Processing Record 38 of Set 5 | hualmay
# Processing Record 39 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 5 | laguna
# Processing Record 41 of Set 5 | synya
# Processing Record 42 of Set 5 | isangel
# Processing Record 43 of Set 5 | bose
# Processing Record 44 of Set 5 | suraabad
# Processing Record 45 of Set 5 | sambava
# Processing Record 46 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 5 | anadyr
# Processing Record 48 of Set 5 | port lincoln
# Processing Record 49 of Set 5 | victoria
# Processing Record 50 of Set 5 | vanimo
# Processing Record 1 of Set 6 | gao
# Processing Record 2 of Set 6 | mountain home
# Processing Record 3 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 5 of Set 6 | mitsamiouli
# Processing Record 6 of Set 6 | menongue
# Processing Record 7 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 6 | griffith
# Processing Record 9 of Set 6 | cartago
# Processing Record 10 of Set 6 | litoral del san juan
# City not found. Skipping...
# Processing Record 11 of Set 6 | muros
# Processing Record 12 of Set 6 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 6 | iqaluit
# Processing Record 14 of Set 6 | shubarshi
# Processing Record 15 of Set 6 | svetlyy
# Processing Record 16 of Set 6 | ostrovnoy
# Processing Record 17 of Set 6 | richards bay
# Processing Record 18 of Set 6 | hobart
# Processing Record 19 of Set 6 | kavieng
# Processing Record 20 of Set 6 | wewak
# Processing Record 21 of Set 6 | stornoway
# Processing Record 22 of Set 6 | bykovo
# Processing Record 23 of Set 6 | goderich
# Processing Record 24 of Set 6 | suez
# Processing Record 25 of Set 6 | comodoro rivadavia
# Processing Record 26 of Set 6 | trinidad
# Processing Record 27 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 6 | elko
# Processing Record 29 of Set 6 | zonguldak
# Processing Record 30 of Set 6 | palu
# Processing Record 31 of Set 6 | gazli
# Processing Record 32 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 6 | simao
# Processing Record 34 of Set 6 | ahipara
# Processing Record 35 of Set 6 | cidreira
# Processing Record 36 of Set 6 | broken hill
# Processing Record 37 of Set 6 | torbay
# Processing Record 38 of Set 6 | inta
# Processing Record 39 of Set 6 | banki
# Processing Record 40 of Set 6 | miraflores
# Processing Record 41 of Set 6 | kruisfontein
# Processing Record 42 of Set 6 | coari
# Processing Record 43 of Set 6 | kieta
# Processing Record 44 of Set 6 | karlstad
# Processing Record 45 of Set 6 | ariano irpino
# Processing Record 46 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 6 | aksehir
# Processing Record 48 of Set 6 | porbandar
# Processing Record 49 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 6 | moyale
# Processing Record 1 of Set 7 | saldanha
# Processing Record 2 of Set 7 | camacha
# Processing Record 3 of Set 7 | tabukiniberu
# City not found. Skipping...
# Processing Record 4 of Set 7 | katangli
# Processing Record 5 of Set 7 | bathsheba
# Processing Record 6 of Set 7 | jiayuguan
# Processing Record 7 of Set 7 | sidi qasim
# City not found. Skipping...
# Processing Record 8 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 9 of Set 7 | nguruka
# Processing Record 10 of Set 7 | ust-omchug
# Processing Record 11 of Set 7 | coalcoman
# City not found. Skipping...
# Processing Record 12 of Set 7 | tsimlyansk
# Processing Record 13 of Set 7 | buzmeyin
# Processing Record 14 of Set 7 | nago
# Processing Record 15 of Set 7 | luderitz
# Processing Record 16 of Set 7 | puerto leguizamo
# Processing Record 17 of Set 7 | luau
# Processing Record 18 of Set 7 | koslan
# Processing Record 19 of Set 7 | bredasdorp
# Processing Record 20 of Set 7 | bubaque
# Processing Record 21 of Set 7 | tres arroyos
# Processing Record 22 of Set 7 | mujiayingzi
# Processing Record 23 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 24 of Set 7 | merritt
# Processing Record 25 of Set 7 | sobolevo
# Processing Record 26 of Set 7 | cabatuan
# Processing Record 27 of Set 7 | melville
# Processing Record 28 of Set 7 | vestmanna
# Processing Record 29 of Set 7 | dicabisagan
# Processing Record 30 of Set 7 | dersca
# Processing Record 31 of Set 7 | verkhnevilyuysk
# Processing Record 32 of Set 7 | ca mau
# Processing Record 33 of Set 7 | ocos
# Processing Record 34 of Set 7 | huron
# Processing Record 35 of Set 7 | asosa
# Processing Record 36 of Set 7 | cap-aux-meules
# Processing Record 37 of Set 7 | hasaki
# Processing Record 38 of Set 7 | nelson bay
# Processing Record 39 of Set 7 | nieuw amsterdam
# Processing Record 40 of Set 7 | poso
# Processing Record 41 of Set 7 | boyolangu
# Processing Record 42 of Set 7 | portland
# Processing Record 43 of Set 7 | srandakan
# Processing Record 44 of Set 7 | kayankulam
# Processing Record 45 of Set 7 | acajutla
# Processing Record 46 of Set 7 | kloulklubed
# Processing Record 47 of Set 7 | shimoda
# Processing Record 48 of Set 7 | hithadhoo
# Processing Record 49 of Set 7 | harper
# Processing Record 50 of Set 7 | kamiiso
# Processing Record 1 of Set 8 | bandarbeyla
# Processing Record 2 of Set 8 | hami
# Processing Record 3 of Set 8 | paamiut
# Processing Record 4 of Set 8 | cercal
# Processing Record 5 of Set 8 | flinders
# Processing Record 6 of Set 8 | bambanglipuro
# Processing Record 7 of Set 8 | umba
# Processing Record 8 of Set 8 | portsmouth
# Processing Record 9 of Set 8 | mahuva
# Processing Record 10 of Set 8 | krasnoselkup
# Processing Record 11 of Set 8 | bluff
# Processing Record 12 of Set 8 | miri
# Processing Record 13 of Set 8 | cabo rojo
# Processing Record 14 of Set 8 | saint-augustin
# Processing Record 15 of Set 8 | yuanping
# Processing Record 16 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 17 of Set 8 | segezha
# Processing Record 18 of Set 8 | zhigansk
# Processing Record 19 of Set 8 | boshnyakovo
# Processing Record 20 of Set 8 | dinguiraye
# Processing Record 21 of Set 8 | rio gallegos
# Processing Record 22 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 23 of Set 8 | abbeville
# Processing Record 24 of Set 8 | cayenne
# Processing Record 25 of Set 8 | gazni
# City not found. Skipping...
# Processing Record 26 of Set 8 | waitati
# Processing Record 27 of Set 8 | wattegama
# Processing Record 28 of Set 8 | kamaishi
# Processing Record 29 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 8 | esperance
# Processing Record 31 of Set 8 | lincoln
# Processing Record 32 of Set 8 | coihaique
# Processing Record 33 of Set 8 | fernandina beach
# Processing Record 34 of Set 8 | berlevag
# Processing Record 35 of Set 8 | oktyabrskiy
# Processing Record 36 of Set 8 | olafsvik
# Processing Record 37 of Set 8 | geraldton
# Processing Record 38 of Set 8 | catabola
# Processing Record 39 of Set 8 | bereda
# Processing Record 40 of Set 8 | seoul
# Processing Record 41 of Set 8 | lorengau
# Processing Record 42 of Set 8 | west lorne
# Processing Record 43 of Set 8 | riyadh
# Processing Record 44 of Set 8 | cerchezu
# Processing Record 45 of Set 8 | salamiyah
# Processing Record 46 of Set 8 | shingu
# Processing Record 47 of Set 8 | kasama
# Processing Record 48 of Set 8 | belmonte
# Processing Record 49 of Set 8 | vila franca do campo
# Processing Record 50 of Set 8 | tetiyiv

# %%
len(city_data)

# %%
# Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head

# %%
city_data_df.columns

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)

# %%
city_data_df.dtypes

# %%
# Create the output File (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
